# %% [markdown]
# <a href="https://colab.research.google.com/github/Miguelangel1208/Entregable_3_-Curso_Inteligencia_artificial/blob/main/Entregable_3_Miguel_Veliz_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Gneración de mapa mental EDOTOR y XMIND

# !ls
# Out:
# sample_data

# %%
from IPython.display import Image
Image('mapa_edotor.png')

# %%
from IPython.display import Image
Image('mapa_xmind.png')

# %% [markdown]
# ##Búsqueda bibliográfica

# %% [markdown]
# Palabras clave: fitorremediacion, fitoextracción, metales pesados, contaminacion del agua, plomo
#
# Keywords: phytoremediation, phytoextraction, heavy metals, water pollution, lead

# %% [markdown]
# ##PySCOPUS

# %%
# !pip install pyscopus==1.0.3a2

# %% [markdown]
# Importar librerías

# %%
from pyscopus import Scopus
import numpy
import pandas
import requests

# %%
key = "070d2de018ba61233277e64da31b55bb"
scopus = Scopus(key)

# %% [markdown]
# Keywords: phytoremediation, phytoextraction, heavy metals, water pollution, lead.
# Búsqueda #1:**Error**
#
# TITLE-ABS-KEY((("polymer") AND ("oil") AND ("water pollution")))
#
# Búsqueda #2:**Arrojó 0 resultados**
#
# TITLE-ABS-KEY((("polymer") AND ("oil") AND ("water pollution") AND ("python")))
#
# Búsqueda #3:**Arrojó 0 resultados**
#
# TITLE-ABS-KEY((("polymer")AND ("surfactant") AND ("oil") AND ("water pollution") AND ("mechanic")))
#
# Búsqueda #4: **Elegido**
#
# TITLE-ABS-KEY((("polymer") AND ("oil") AND ("water pollution") AND ("mechanic")))

# %%
s = input("Ingresa tus palabras de búsqueda: ")
search_df = scopus.search(s, count=200,view='STANDARD')
# Out:
# Ingresa tus palabras de búsqueda: TITLE-ABS-KEY((("polymer") AND ("oil") AND ("water pollution") AND ("mechanic")))

# %%
from IPython.display import display
display(search_df)
# Out:
#      scopus_id                                              title  \
# 0  85133295240  Fluoropolymer-based hybrid superhydrophobic na...
# 1  85107582040  Fabrication of outstanding thermal-insulating,...
# 2  85074845154  Preparation of a Phenolic-Resin-Based Polymer ...
# 3  85019959267  Thermoresponsive Microcarriers for Smart Relea...
# 4  84973299891  Functions of soymeal compositions in textile s...
# 5  84896373704  2014 3rd International Conference on Intellige...
# 6  49649117542  Experimental validation of theoretical models ...
# 7  50949109962  Reclamation of the polymer-flooding produced w...
#
#                                     publication_name      issn  \
# 0  Colloids and Surfaces A: Physicochemical and E...  09277757
# 1                     Journal of Hazardous Materials  03043894
# 2                                           Langmuir  07437463
# 3               ACS Applied Materials and Interfaces  19448244
# ...

# %%
search_df.shape
# Out:
# (8, 16)

# %% [markdown]
# Instalando dependencias

# %%
# %%capture
# !pip install -U "transformers==4.40.0" --upgrade
# !pip install -i https://pypi.org/simple/ bitsandbytes
# !pip install accelerate

# %%
#@title Cargando LLAMA3
import transformers
import torch

model_id = "unsloth/llama-3-8b-Instruct-bnb-4bit"

pipeline = transformers.pipeline(
    "text-generation",
    model=model_id,
    model_kwargs={
        "torch_dtype": torch.float16,
        "quantization_config": {"load_in_4bit": True},
        "low_cpu_mem_usage": True,
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# /usr/local/lib/python3.10/dist-packages/transformers/quantizers/auto.py:159: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.
#   warnings.warn(warning_msg)
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/220 [00:00<?, ?B/s]
# ...

# %% [markdown]
# PREGUNTAS:
#
# 1) ¿Cuáles son las principales limitaciones de los materiales hidrófobos biomiméticos utilizados en la separación de mezclas de aceite y agua, y qué ventajas presentan los compuestos híbridos orgánico-inorgánicos en comparación con los métodos convencionales?
#
# 2)¿Cuáles son las principales categorías de absorbentes poliméricos porosos para la separación de aceite y agua, y cuáles son sus ventajas y limitaciones más destacadas en el tratamiento de aguas residuales oleosas?
#
# 3) ¿Qué métodos existen para recuperar petróleo y que polimero se recomienda?

# %% [markdown]
# # Artículo 1 de la tabla

# %%
context1 = r"""El aumento masivo de la producción de mezclas de petróleo/agua en las operaciones domésticas e industriales se ha convertido en un problema mundial, ya que no solo altera los ecosistemas y afecta la salud humana, sino que también desperdicia cantidades significativas de recursos vitales necesarios para el desarrollo[1], [2], [3]. Los métodos competentes para separar las mezclas de petróleo/agua se han vuelto necesarios para mantener el desarrollo sostenible y minimizar estos efectos ambientales adversos. Los métodos de separación convencionales que incluyen el método dispersante[4], se han adoptado previamente para frenar este problema. Sin embargo, estos métodos tienen limitaciones de contaminación ambiental secundaria donde los subproductos químicos se liberan de nuevo en los cuerpos de agua, lo que resulta en la interrupción del equilibrio del ecosistema al agotar el nivel de oxígeno [5], [6].El método de extracción física ha demostrado ser ideal en la separación de mezclas de aceite y agua, pero con el método de desnatado que requiere mucha energía mecánica que también produce problemas de eficiencia energética [7], [5], [8]. Los materiales hidrófobos biomiméticos recientemente desarrollados como métodos de extracción física han atraído una amplia atención debido a su absorción selectiva de aceite y repelencia de agua [9], [10], [11], [12].
Al explorar materiales biomiméticos hidrófobos para separaciones de aceite/agua, se han logrado muchos trabajos exitosos como aerogeles hidrófobos [13], membranas porosas con humectabilidad personalizada [14], materiales recubiertos con CNT e hidrogeles hidrófobos [15]. Hasta el momento, se han logrado diversos grados de éxito con materiales hidrófobos en aplicaciones de separación de aceite/agua, sin embargo, todavía existen limitaciones inevitables, como un alto costo de producción, baja eficiencia de separación y poca robustez mecánica de los materiales [16], [17], [12]. El uso de equipos sofisticados junto con materias primas costosas para fabricar la rugosidad y la baja energía superficial en sustratos para obtener las propiedades biomiméticas han llevado al alto costo de producción en esta área [12].Aunque el desarrollo reciente en este campo se está moviendo hacia métodos de fabricación más económicos, los medios fáciles y simples aún no han podido cumplir con las propiedades robustas requeridas y poseen una naturaleza delicada en sus superficies, por lo tanto, sufre una vida útil corta en presencia de estrés mecánico [18]. Algunos de estos contratiempos han paralizado la realización industrial del uso de materiales hidrófobos biomiméticos para la separación de aceite/agua. Los nuevos materiales biomiméticos hidrófobos que son rentables, duraderos y reutilizables siguen siendo muy buscados para una separación eficiente de aceite/agua.Algunos de estos contratiempos han paralizado la realización industrial del uso de materiales hidrófobos biomiméticos para la separación de aceite/agua. Los nuevos materiales biomiméticos hidrófobos que son rentables, duraderos y reutilizables siguen siendo muy buscados para una separación eficiente de aceite/agua.Algunos de estos contratiempos han paralizado la realización industrial del uso de materiales hidrófobos biomiméticos para la separación de aceite/agua. Los nuevos materiales biomiméticos hidrófobos que son rentables, duraderos y reutilizables siguen siendo muy buscados para una separación eficiente de aceite/agua.
La búsqueda de materiales biomiméticos hidrófobos rentables con alta robustez mecánica ha llevado a la incorporación de nanopartículas inorgánicas en matrices de polímeros para sintetizar compuestos híbridos orgánico-inorgánicos para diversas aplicaciones [19]. Los compuestos híbridos orgánico-inorgánicos poseen estabilidades mecánicas y químicas de sus membranas, aprovechando las propiedades de los materiales binarios [19], [20]. Como resultado, el desarrollo de compuestos híbridos superhidrofóbicos para evitar la humectación de la membrana para diversas aplicaciones, incluida la separación de aceite/agua, es muy solicitado [21], [22]. Los fluoropolímeros, especialmente el PVDF con propiedades intrínsecas, se han convertido en uno de los polímeros más utilizados para los compuestos híbridos [22], [23], [24].Entre varios materiales inorgánicos que se combinan con PVDF para compuestos híbridos, incluido el óxido de aluminio (Al2O3) [25] y óxido de titanio (TiO2) [26], óxido de silicio (SiO2) ha surgido como el más convenientemente utilizado debido a su reactividad suave y propiedades químicas[27]. Por ejemplo, Li et al. [28] utilizaron adsorción electrostática y unión química para recubrir una capa de SiO2 nanopartículas en la superficie de la membrana de PVDF, y luego fluoraron las membranas con 1 H,1 H,2 H,2 H perfluorodeciltrietoxisilano para generar una membrana superhidrofóbica con una hidrofobicidad de > 150˚. Pan et al. [22] fabricaron recientemente una matriz mixta superhidrofóbica PVDF-SiO2membrana de fibra hueca HDTMS mediante la introducción de amoníaco en una droga de PVDF para deshidrofluorar primero PVDF para permitir SiO hidrófilo2 mezclar bien con PVDF antes de la introducción de HDTMS para obtener hidrofobicidad. B. Lin et al. también fabricaron un SiO2/Nanocmpuesto de PVDF en la superficie de la esponja de celulosa con un ángulo de contacto de 154.3˚ para la separación de aceite/agua con 36 veces la reutilización [29]. Sin embargo, los métodos para fabricar recubrimientos de nanocompuestos a base de fluoropolímero, como la mezcla y el curado, hasta la fecha tienen algunas limitaciones. Significativamente, la deshidrofluoración inicial del fluoropolímero disminuye la resistencia mecánica de la membrana [30]. Sin embargo, debe tenerse en cuenta que la adición de nanopartículas inorgánicas a un polímero orgánico, formando un marco inorgánico no debe tener una disminución aparente en las propiedades del polímero [31], [32]. Además, las nanopartículas en la superficie del recubrimiento están enterradas principalmente en la resina de la matriz, lo que reduce drásticamente su superhidrofobicidad y afecta su aplicación práctica [33].Esto afecta significativamente la eficiencia y durabilidad de los materiales superhidrofóbicos y lo cual es bastante evidente en sus aplicaciones en problemas de separación de aceite/agua. ¿Existe una mejor manera de sintetizar un compuesto híbrido superhidrofóbico sin tener que distorsionar las propiedades de los materiales binarios o ternarios involucrados para una aplicación efectiva y eficiente de separación de aceite/agua? Aquí se informa de nuestro esfuerzo para abordar esta cuestión de investigación y la aplicación de los recubrimientos superhidrofóbicos resultantes en la separación de aceite/agua.¿Existe una mejor manera de sintetizar un compuesto híbrido superhidrofóbico sin tener que distorsionar las propiedades de los materiales binarios o ternarios involucrados para una aplicación efectiva y eficiente de separación de aceite/agua? Aquí se informa de nuestro esfuerzo para abordar esta cuestión de investigación y la aplicación de los recubrimientos superhidrofóbicos resultantes en la separación de aceite/agua.¿Existe una mejor manera de sintetizar un compuesto híbrido superhidrofóbico sin tener que distorsionar las propiedades de los materiales binarios o ternarios involucrados para una aplicación efectiva y eficiente de separación de aceite/agua? Aquí se informa de nuestro esfuerzo para abordar esta cuestión de investigación y la aplicación de los recubrimientos superhidrofóbicos resultantes en la separación de aceite/agua.
En este trabajo, diseñamos y fabricamos un compuesto híbrido superhidrofóbico orgánico-inorgánico (O-ISHC) fácil y rentable para recubrir el papel de filtro de celulosa para una separación efectiva de aceite/agua. Debido a la fácil accesibilidad y la amplia gama de aplicaciones del papel de filtro en los campos de envasado, almacenamiento y entrega de información, el papel a base de celulosa se ha convertido en un componente integral del sustento diario [34], [35], [36]. Sin embargo, dada la presencia de un gran número de grupos hidroxilo en la superficie de los papeles a base de celulosa (por ejemplo, papel de filtro), existe una alta afinidad por los líquidos, lo que reduce su resistencia en la mayoría de las aplicaciones [37], pero la modificación de su superficie puede ampliar su alcance de aplicaciones, por lo tanto, un sustrato adecuado elegido para este trabajo.El procedimiento utilizado en la síntesis del compuesto híbrido superhidrofóbico proviene de trabajos pioneros de nanopartículas de sílice hidrófobas, específicamente el método Stöber [38]. Este método es la técnica sintética bien establecida y fácil a partir de la cual se pueden procesar materiales inorgánicos y polímeros orgánicos - inorgánicos (híbridos) o nanocompuestos para formar nanopartículas, recubrimientos, fibras o materiales a granel para la producción a gran escala [39], [40]. Particularmente, recubrimos nanopartículas de sílice con alquilsilanos de cadena larga y polidimetilsiloxano (PDMS) utilizando esta técnica de sol-gel para proporcionar un sol-gel superhidrofóbico precursor. Además, mezclamos una droga de PVDF con la solución precursora para formar un compuesto híbrido orgánico-inorgánico. Debido a una nueva fase cristalina (fase b) de PVDF y un nuevo grupo de CDebido a una nueva fase cristalina (b-fase) de PVDF y un nuevo grupo de CDebido a una nueva fase cristalina (b-fase) de PVDF y un nuevo grupo de CEste método es la técnica sintética bien establecida y fácil a partir de la cual se pueden procesar materiales inorgánicos y polímeros orgánicos - inorgánicos (híbridos) o nanocompuestos para formar nanopartículas, recubrimientos, fibras o materiales a granel para la producción a gran escala [39], [40]. Particularmente, recubrimos nanopartículas de sílice con alquilsilanos de cadena larga y polidimetilsiloxano (PDMS) utilizando esta técnica de sol-gel para proporcionar un sol-gel superhidrofóbico precursor. Además, mezclamos una droga de PVDF con la solución precursora para formar un compuesto híbrido orgánico-inorgánico. Debido a una nueva fase cristalina (fase b) de PVDF y un nuevo grupo de CEste método es la técnica sintética bien establecida y fácil a partir de la cual se pueden procesar materiales inorgánicos y polímeros orgánicos - inorgánicos (híbridos) o nanocompuestos para formar nanopartículas, recubrimientos, fibras o materiales a granel para la producción a gran escala [39], [40]. Particularmente, recubrimos nanopartículas de sílice con alquilsilanos de cadena larga y polidimetilsiloxano (PDMS) utilizando esta técnica de sol-gel para proporcionar un sol-gel superhidrofóbico precursor. Además, mezclamos una droga de PVDF con la solución precursora para formar un compuesto híbrido orgánico-inorgánico. Debido a una nueva fase cristalina (fase b) de PVDF y un nuevo grupo de Co materiales a granel para la producción a gran escala [39], [40]. Particularmente, recubrimos nanopartículas de sílice con alquilsilanos de cadena larga y polidimetilsiloxano (PDMS) utilizando esta técnica de sol-gel para proporcionar un sol-gel superhidrofóbico precursor. Además, mezclamos una droga de PVDF con la solución precursora para formar un compuesto híbrido orgánico-inorgánico. Debido a una nueva fase cristalina (fase b) de PVDF y un nuevo grupo de Co materiales a granel para la producción a gran escala [39], [40]. Particularmente, recubrimos nanopartículas de sílice con alquilsilanos de cadena larga y polidimetilsiloxano (PDMS) utilizando esta técnica de sol-gel para proporcionar un sol-gel superhidrofóbico precursor. Además, mezclamos una droga de PVDF con la solución precursora para formar un compuesto híbrido orgánico-inorgánico. Debido a una nueva fase cristalina (fase b) de PVDF y un nuevo grupo de Cdoble enlaceC se forma en el tratamiento térmico [41], se convierte en el material ideal para una mezcla perfecta en la formación de un compuesto híbrido con el precursor hidrófobo SiO2 sin necesidad de deshidrofluoración. Registramos una fuerte afinidad entre el SiO hidrófobo2 y PVDF, como resultado, nano-SiO2 las partículas se anclaron fácilmente en las cadenas de PVDF debido al excelente efecto de reticulación de PVDF. El ángulo de contacto con el agua obtenido para el compuesto híbrido sintetizado en la superficie del papel de filtro fue de 161˚. El material recubierto también se incorporó con alta resistencia mecánica y estabilidad ácida/alcalina para la aplicación de separación de aceite/agua."""

# %%
#@title Pregunta 1
messages = [
    {"role"   : "system",
     "content": context1},
    {"role"   : "user",
     "content": """¿Cuáles son las principales limitaciones de los materiales hidrófobos biomiméticos utilizados en la separación de mezclas de aceite y agua, y qué ventajas presentan los compuestos híbridos orgánico-inorgánicos en comparación con los métodos convencionales?"""},
]



prompt = pipeline.tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
)

terminators = [
    pipeline.tokenizer.eos_token_id,
    pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
]

outputs = pipeline(
    prompt,
    max_new_tokens=256,
    eos_token_id=terminators,
    do_sample=True,
    temperature=0.6,
    top_p=0.9,
)

print(outputs[0]["generated_text"][len(prompt):])
# Out:
# Las principales limitaciones de los materiales hidrófobos biomiméticos utilizados en la separación de mezclas de aceite y agua son:
#
# 1. Alto costo de producción: La fabricación de materiales hidrófobos biomiméticos requiere la utilización de equipos sofisticados y materias primas costosas, lo que lo hace poco accesible para aplicaciones industriales.
# 2. Baja eficiencia de separación: Los materiales hidrófobos biomiméticos pueden tener una baja capacidad para separar mezclas de aceite y agua, lo que puede requerir la utilización de cantidades significativas de agua para la separación.
# 3. Poca robustez mecánica: Los materiales hidrófobos biomiméticos pueden ser delicados y sufrir daños mecánicos, lo que reduce su vida útil y su capacidad para separar mezclas de aceite y agua.
# 4. Contaminación ambiental secundaria: Los métodos convencionales de separación pueden liberar subproductos químicos en los cuerpos de agua, lo que puede afectar el equilibrio ecológico.
# ...

# %% [markdown]
# # Artículo 2 de la tabla

# %%
context2 = r"""Las aguas residuales oleosas, como un contaminante mundial y extremadamente común producido por muchos campos, como la minería, los alimentos, la exploración y el transporte de petróleo, los productos petroquímicos y los industriales metálicos, son una catástrofe potencial para el medio ambiente y, mientras tanto, un gran desperdicio de energía y recursos (Chen y Xu, 2013, Feng et al., 2015, Rizvi et al., 2014). Tomando como ejemplo los derrames de petróleo, alrededor de 20,000 toneladas de diesel se derramaron accidentalmente de una planta de energía rusa cerca del Círculo Polar Ártico, lo que dañaría seriamente el ecosistema marino y amenazaría la supervivencia de las criaturas independientemente del desperdicio de energía (Ejeromedoghene et al., 2020). Por lo tanto, la remediación de las aguas residuales oleosas es de importancia práctica para la protección del medio ambiente, así como para el desarrollo sostenible de la economía y la sociedad. Para abordar este problema asociado,se han desarrollado y empleado numerosos métodos para la eliminación de aceite del agua y nuevos materiales para mitigar el impacto adverso de las aguas residuales oleosas en entornos globales (Jiang et al., 2016, Jiang et al., 2017, Jiang et al., 2019). Un enfoque industrial para la limpieza de derrames de petróleo es emplear equipos mecánicos (es decir, booms y skimmers de petróleo), mientras que su baja eficiencia de separación y requisitos específicos, como grandes cantidades de entrada de energía y alta presión para operar, restringen la aplicación a gran escala (Ventikos et al., 2004). Otro enfoque común y práctico es utilizar materiales porosos, incluidos algodón/lana (Choi y Cloud, 1992, Radetic et al., 2003), mallas/membranas (Lu et al., 2015), esponjas (Nguyen et al., 2012, Zhu et al., 2013) y espumas (Calcagnile et al., 2012, Hu et al., 2019), como absorbentes para el secuestro de aceite por sorción.Algunos de los materiales absorbentes porosos se han aclarado como materiales candidatos para separar mezclas de solventes/agua que poseen sus propiedades ecológicas, rentables, reutilizables y de separación fácil (Feng et al., 2015, Rizvi et al., 2014).
Los absorbentes porosos actualmente reportados se pueden dividir aproximadamente en 3 categorías, incluidos los absorbentes naturales, los materiales porosos sintéticos 2D y 3D. Absorbentes naturales como paja, fibrillas de algodón/lana, mazorcas de maíz, fibrillas de celulosa/kapok e hilo de algodoncillo (Choi y Cloud, 1992, Lim y Huang, 2007, Payne et al., 2012), son los materiales utilizados para la limpieza de derrames de petróleo en los primeros días debido a su alta degradabilidad bajo la intemperie natural. Sin embargo, sufren intrínsecamente una pobre selectividad de aceite/agua, baja capacidad de absorción y reutilización, lo que podría limitar drásticamente su efectividad en el tratamiento de aguas residuales oleosas (Adebajo et al., 2003, Chandrasekar et al., 2017, Xu et al., 2015). En cuanto a materiales 2D como mallas y membranas (Duong et al., 2014, Lu et al., 2016, Zhang et al., 2013), gracias a su bajo costoalta eficiencia de separación y proceso de producción simple, desempeñan un papel importante en la separación industrial de la vida real de mezclas de aceite/agua (Abidli et al., 2020, Oliveira et al., 2021). Desafortunadamente, el mecanismo de separación de aceite/agua de los materiales porosos 2D, que necesita recolectar toda el agua contaminada con aceite antes de separar el aceite del agua, aumenta su dificultad en la eliminación del derrame de petróleo ambiental externo (Feng et al., 2015). Sin embargo, los materiales porosos 3D, que incluyen principalmente esponjas (Chen et al., 2019, Gui et al., 2011), aerogeles (Cao et al., 2021, Zhang et al., 2021) y espumas (Hou et al., 2019a, Rizvi et al., 2014), superan las restricciones anteriores en las condiciones de aplicaciónlos cuales exhiben enormes ventajas para prevenir catástrofes causadas por fugas de petróleo a bajo costo en comparación con los absorbentes sintéticos 2D comunes, ya que pueden absorber el petróleo de manera efectiva simplemente colocándolos en las áreas contaminadas con petróleo sin ningún dispositivo especializado (Feng et al., 2015, Hou et al., 2015, Lu et al., 2014). Se espera que los materiales sintéticos 3D representen una oportunidad para desarrollar absorbentes ecológicos, fáciles, reciclables y de alta eficiencia para la purificación de mezclas de aceite/agua con altas tasas de flujo.y absorbentes de alta eficiencia para la purificación de mezclas de aceite/agua con altas tasas de flujo.y absorbentes de alta eficiencia para la purificación de mezclas de aceite/agua con altas tasas de flujo.
Entre los absorbentes sintéticos 3D mencionados, a pesar de que las esponjas de carbono y los aerogeles muestran capacidades de separación de solventes/agua con una capacidad de absorción de aceite de más de 130 g/g y una eficiencia de separación de hasta 98.8% (Gui et al., 2011, Wang et al., 2016b) su alto costo resultante de procesos sintéticos complejos y propiedades mecánicas deficientes están desafiando las aplicaciones mundiales (Bi et al., 2012, Camilli et al., 2014, He et al., 2018, Wu et al., 2013). En este contexto, la espuma a base de polímero se ha convertido en un candidato prometedor para la utilización generalizada en la limpieza de derrames de petróleo, ya que tiene ventajas que incluyen bajos costos de material y fabricación, excelente rendimiento mecánico y reutilización, y una pronunciada capacidad de separación de la mezcla de aguas residuales oleosas (Hou et al., 2015, Li et al., 2014, Wu et al., 2015;).La espuma de poliuretano (PU) es uno de los absorbentes sintéticos a base de polímeros más comunes para la eliminación de derrames de petróleo. Muestra muchas ventajas, como alta capacidad de flotación y absorción, bajo costo y densidad, y producción fácilmente escalable. Sin embargo, la escasa humectabilidad de la superficie y la característica termoestable de las espumas de PU limitan su aplicación en la limpieza de derrames de petróleo (Zhang et al., 2013, Zhu et al., 2011b). Aunque un par de métodos, incluyendo la deposición química de vapor (Li et al., 2014, Wu et al., 2015), recubrimiento por inmersión (Ge et al., 2015, Hou et al., 2015; Zhu y Guo, 2014), la adición de nanopartículas (Wang et al., 2016a; Zhu y Pan, 2014), injerto (Wang et al., 2014a), y sol-gel funcionalización (Wu et al., 2015; Zhu y Guo, 2014), se han aplicado para promover la eficiencia de separación de la espuma de PU mediante el aumento de su hidrofobicidadsu reutilización, estabilidad de rendimiento y rentabilidad se ven afectadas por estas modificaciones. Además, dicha modificación también podría introducir contaminantes adicionales que limitan aún más la aplicación de espumas de PU como absorbentes de aceite (Feng et al., 2015). Teniendo en cuenta estas deficiencias de los absorbentes 3D existentes (Feng et al., 2015, Li et al., 2014, Wang et al., 2016b, Wu et al., 2015), el desarrollo de materiales porosos avanzados a través de métodos sintéticos simples y respetuosos con el medio ambiente que utilizan polímeros termoplásticos comunes (por ejemplo, polipropileno PP) presenta un futuro prometedor para el ahorro de energía y la protección del medio ambiente con alta eficiencia y bajo costo.dicha modificación también podría introducir contaminantes adicionales que limitan aún más la aplicación de espumas de PU como absorbentes de aceite (Feng et al., 2015). Teniendo en cuenta estas deficiencias de los absorbentes 3D existentes (Feng et al., 2015, Li et al., 2014, Wang et al., 2016b, Wu et al., 2015), el desarrollo de materiales porosos avanzados a través de métodos sintéticos simples y respetuosos con el medio ambiente que utilizan polímeros termoplásticos comunes (por ejemplo, polipropileno PP) presenta un futuro prometedor para el ahorro de energía y la protección del medio ambiente con alta eficiencia y bajo costo.dicha modificación también podría introducir contaminantes adicionales que limitan aún más la aplicación de espumas de PU como absorbentes de aceite (Feng et al., 2015). Teniendo en cuenta estas deficiencias de los absorbentes 3D existentes (Feng et al., 2015, Li et al., 2014, Wang et al., 2016b, Wu et al., 2015), el desarrollo de materiales porosos avanzados a través de métodos sintéticos simples y respetuosos con el medio ambiente que utilizan polímeros termoplásticos comunes (por ejemplo, polipropileno PP) presenta un futuro prometedor para el ahorro de energía y la protección del medio ambiente con alta eficiencia y bajo costo.el desarrollo de materiales porosos avanzados a través de métodos sintéticos simples y respetuosos con el medio ambiente que utilizan polímeros termoplásticos comunes (por ejemplo, polipropileno PP) presenta un futuro prometedor para el ahorro de energía y la protección del medio ambiente con alta eficiencia y bajo costo.el desarrollo de materiales porosos avanzados a través de métodos sintéticos simples y respetuosos con el medio ambiente que utilizan polímeros termoplásticos comunes (por ejemplo, polipropileno PP) presenta un futuro prometedor para el ahorro de energía y la protección del medio ambiente con alta eficiencia y bajo costo.
Este trabajo se centró en la explotación ecológica de materiales sobresalientes de separación de petróleo/agua utilizando la matriz de PP rentable y fuerte para revolucionar la protección del medio ambiente mediante el control de la contaminación, la reducción de emisiones y el ahorro de energía. Los nanocompuestos PP con nanotubos de carbono (CNT) y derivados de sorbitol que contribuyen principalmente a lograr espumas de células abiertas se prepararon primero, y posteriormente, la espuma microcelular fácil y ecológica con dióxido de carbono (CO2) como agente de soplado físico se empleó para fabricar espumas de nanocompuesto derivadas de PP y PP/CNT/sorbitol. Al caracterizar la estructura celular, la absorción de aceite y el rendimiento de separación de aceite/agua, las propiedades térmicas aislantes y mecánicas, el nanocompuesto de PP microcelular ultraligero con capacidad de absorción y separación de alta eficiencia, conductividad térmica súper baja y resistencia a la compresión excepcional se pueden fabricar para un desarrollo saludable y sostenible que vincule el medio ambiente, la sociedad y la economía."""

# %%
#@title Pregunta 2
messages = [
    {"role"   : "system",
     "content": context1},
    {"role"   : "user",
     "content": """¿Cuáles son las principales categorías de absorbentes poliméricos porosos para la separación de aceite y agua, y cuáles son sus ventajas y limitaciones más destacadas en el tratamiento de aguas residuales oleosas?"""},
]



prompt = pipeline.tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
)

terminators = [
    pipeline.tokenizer.eos_token_id,
    pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
]

outputs = pipeline(
    prompt,
    max_new_tokens=256,
    eos_token_id=terminators,
    do_sample=True,
    temperature=0.6,
    top_p=0.9,
)

print(outputs[0]["generated_text"][len(prompt):])
# Out:
# Las principales categorías de absorbentes poliméricos porosos para la separación de aceite y agua son:
#
# 1. **Materiales hidrófobos**: Estos materiales tienen una superficie hidrófoba que repele el agua y atrae el aceite. Ejemplos incluyen membranas de poli(vinilideno) (PVDF) y poli(dimetilsiloxano) (PDMS).
# 2. **Materiales hidrófilos**: Estos materiales tienen una superficie hidrófila que atrae el agua y repele el aceite. Ejemplos incluyen membranas de poli(acrilato) (PAA) y poli(vinilpirrolidona) (PVP).
# 3. **Materiales superhidrofóbicos**: Estos materiales tienen una superficie muy hidrófoba que repele tanto el agua como el aceite. Ejemplos incluyen membranas de poli(tetrafluoroetilo) (PTFE) y poli(perfluorosiloxano) (PPSO).
# 4. **Materiales nanocompuestos**: Estos materiales combinan nanopartícul

# %% [markdown]
# # Artículo 7 de la tabla

# %%
context3 = r"""En la extracción de petróleo crudo, se puede inyectar agua en el estrato para expulsar el petróleo crudo del suelo, lo que a menudo se denomina proceso de inundación por agua o extracción secundaria de petróleo. El contenido de petróleo disminuye después de que la extracción secundaria ha operado durante un tiempo. Para mejorar la recuperación del petróleo, se emplea posteriormente la inundación con polímeros (agua inyectada que contiene polímero) y la inundación con polímeros-alcalinos-surfactantes (agua inyectada que contiene polímeros, alcalinos y surfactantes), lo que comúnmente se conoce como extracción terciaria de petróleo. Experiencias industriales muestran que la inundación con polímeros puede mejorar la recuperación de petróleo en hasta un 12% y juega un papel clave en la explotación petrolera [1,2]. Esta tecnología se ha utilizado ampliamente en el campo petrolífero de Daqing en China en los últimos años [3-5]. Las estadísticas recientes muestran que la producción de petróleo mediante inundación con polímeros en China alcanzó los 10×10⁶ toneladas en 2006, y el campo petrolífero de Daqing tiene el mayor proyecto de inundación con polímeros del mundo. La Figura 1 ilustra el proceso de extracción terciaria de petróleo mediante inundación con polímeros y el tratamiento del agua producida. Se disuelve una gran cantidad de polímero (poliacrilamida hidrolizada, HPAM) en agua para aumentar la viscosidad de la solución antes de inyectar el agua en el estrato a través de los pozos de agua. Luego, la solución de HPAM con algo de petróleo crudo se extrae de los pozos petroleros. El líquido producido se convierte en agua producida (aguas residuales oleosas) después del proceso de deshidratación utilizando separadores trifásicos. Y el agua producida se convierte en agua producida por inundación con polímeros (PFPW) después de ser tratada. La PFPW contiene polímero, aceite, calcio, magnesio, carbonatos, entre otros. Después de la eliminación de aceite, grasas, sólidos suspendidos y compuestos orgánicos, la PFPW es el contenido investigado. Hay pocos efectos del HPAM en el tratamiento de la PFPW mediante la tecnología de cuatro grados de EDR y los efectos del HPAM se describen en otro artículo [6]. La alta concentración de sólidos disueltos totales (TDS) en el agua producida sigue siendo un desafío en el tratamiento para su uso beneficioso. Es bien sabido que existe una relación entre la viscosidad y los TDS de la PFPW. Cuando los TDS son un poco más altos, la viscosidad es un poco más baja, y viceversa [7]. Sin embargo, la viscosidad es uno de los parámetros más importantes para lograr la inundación con polímeros. Los resultados experimentales simulados mostraron que cuando los TDS son menores que los del agua superficial, ya sea en términos de viscosidad o capacidad de resistencia al cizallamiento, la calidad de la PFPW puede cumplir con todas las condiciones para la solución polimérica en campos petroleros. Por lo tanto, se puede considerar que la eliminación de TDS es el problema clave para reutilizar la PFPW. Las tecnologías de separación actualmente disponibles para desalinizar el agua producida incluyen filtración con membrana de bentonita [8], ósmosis inversa [9,10-12], y electrodiálisis (ED) [6]. La mayor parte del trabajo publicado sobre la eliminación de TDS del agua producida en campos petroleros se ha abordado con el uso de ósmosis inversa, y se han realizado pocas pruebas a gran escala de electrodiálisis para esta aplicación [6]. La reducción de TDS en el agua producida mediante ED es el punto focal de este artículo. En la ED, los electrolitos se transfieren a través de un sistema de soluciones y membranas de intercambio iónico mediante un gradiente de potencial eléctrico aplicado. Una pila de ED consta de membranas de intercambio catiónico, que son permeables a los iones cargados positivamente pero no a los cargados negativamente, y membranas de intercambio aniónico, que son permeables a los iones cargados negativamente pero no a los cargados positivamente. En la pila, las membranas de intercambio catiónico alternan con las membranas de intercambio aniónico para formar compartimentos de solución. Cuando se aplica un potencial eléctrico entre los electrodos en los extremos de la pila, todos los cationes en la solución que circula a través de la pila tienden a moverse hacia el cátodo y todos los aniones tienden a migrar hacia el ánodo. Los cationes que migran a través de las membranas de intercambio catiónico hacia el cátodo son rechazados por las membranas de intercambio aniónico; simultáneamente, los aniones que pasan a través de las membranas de intercambio aniónico hacia el ánodo son rechazados por las membranas de intercambio catiónico. Como resultado, la depleción y concentración de iones se logran en compartimentos de solución alternos. Las corrientes de dilución de los compartimentos alternos se combinan y distribuyen de nuevo a los mismos compartimentos para eliminar continuamente los iones de la dilución. Un proceso análogo ocurre para aumentar continuamente los iones en el concentrado [13]. Para reducir el riesgo de formación de incrustaciones causadas por la polarización de la concentración y la adsorción de sólidos suspendidos, este sistema adopta la tecnología de reversión de electrodiálisis de cuatro grados y cuatro segmentos (cuatro GS) para desalinizar la PFPW. A través de los resultados de las pruebas, la conductividad de la PFPW tratada fue inferior a 1.3 mS/cm y el consumo de energía para producir 1 m³ de PFPW diluida tratada fue inferior a 1 kW·h. Manteniendo la relación de flujo entre la PFPW concentrada y la PFPW diluida tratada en 1:1, así como variando el caudal y el voltaje, se midió la tasa de eliminación bajo diferentes caudales. Se estudiaron las condiciones óptimas de operación. En condiciones óptimas, se analizaron los usos disponibles de la PFPW diluida tratada y la PFPW concentrada tratada."""

# %%
#@title Pregunta 3
messages = [
    {"role"   : "system",
     "content": context1},
    {"role"   : "user",
     "content": """¿Qué métodos existen para recuperar petróleo y que polimero se recomienda?"""},
]



prompt = pipeline.tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
)

terminators = [
    pipeline.tokenizer.eos_token_id,
    pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
]

outputs = pipeline(
    prompt,
    max_new_tokens=256,
    eos_token_id=terminators,
    do_sample=True,
    temperature=0.6,
    top_p=0.9,
)

print(outputs[0]["generated_text"][len(prompt):])
# Out:
# Hay varios métodos para recuperar petróleo, dependiendo de la composición del petróleo y las condiciones del medio. Algunos de los métodos más comunes son:
#
# 1. **Separación de aceite/agua**: este método implica separar el petróleo de la agua y otros líquidos que se encuentran en la mezcla. Los materiales hidrófobos, como los fluoropolímeros, son comúnmente utilizados para este propósito.
# 2. **Filtración**: este método implica utilizar un filtro para separar el petróleo de la agua y otros líquidos. Los materiales hidrófobos, como los fluoropolímeros, también se utilizan en este método.
# 3. **Destilación**: este método implica calentando el petróleo para separar los componentes más volátiles de los menos volátiles.
# 4. **Extracción**: este método implica utilizar un solvente para separar el petróleo de la agua y otros líquidos.
#
# En cuanto a los polímeros recomendados, algunos de los más comunes son:
#
# 1. **Polivinilideno (PV
